# %% [markdown]
# # **Book Core Assignment**

# %% [markdown]
# Joe Lardie
#
# Feb 2023

# %% [markdown]
# ## **Imports**

# %%
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

# %% [markdown]
# ## **loading Data**

# %%
username = "root"
password = "Root"
db_name = ""
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
cd = pd.read_csv('',sep='\t', low_memory = False)

# %% [markdown]
# ## **

# %% [markdown]
# ![Books_png.png](attachment:Books_png.png)
